# %% [markdown]
# # Part - 1
# EDA & Data Preprocessing on Google App Store Rating Dataset.

# %% [markdown]
# # Question 1
# 1.Import required libraries and read the dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv("Google_playstore_appdata.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # Question 2
# 2.Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
#shape
df.shape
# Out:
# (10841, 13)

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# # Question 3
# 3.Check summary statistics of the dataset. List out the columns that need to be worked upon for model
# building.

# %%
#Summary Statistics
df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
model_building = ['Category','Rating','Size','Installs','Type','Price','Content Rating','Genres','Last Updated',
                                  'Current Ver','Android Ver']
df[model_building].columns
# Out:
# Index(['Category', 'Rating', 'Size', 'Installs', 'Type', 'Price',
#        'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# # My Inferences for 3rd Question :
# * The goal of model building is to create a model that can accurately predict the output of a system, given the input data.
# * From the above dataset, the app column represents the application name. Hence, with the app column we are not going to predict anything.
# * So, Except the app column, all the other columns (Category, Rating, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver) are needed for model building.

# %% [markdown]
# # Question 4
# 4.Check if there are any duplicate records in the dataset? if any drop them

# %%
df.duplicated().sum()
# Out:
# 483

# %% [markdown]
# * There are 483 duplicate in the dataset.

# %%
df.drop_duplicates(inplace = True)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * Since we are getting 483 duplicated records in the dataset, so, the duplicated records were dropped in the same dataframe.

# %% [markdown]
# # Question 5
# 5.Check the unique categories of the column 'Category', Is there any invalid category? If yes, drop them.

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df=df.drop(df[df['Category']=='1.9'].index)

# %% [markdown]
# * Since, the category column has 1 invalid category ("1.9"), we dropped it.

# %% [markdown]
# # Question 6
# 6.Check if there are missing values present in the column Rating, If any? drop them and and create a new
# column as 'Rating_category' by converting ratings to high and low categories(>3.5 is high rest low)

# %%
df['Rating'].isnull().sum()
# Out:
# 1465

# %%
df = df.dropna(subset=['Rating'], axis=0)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[['Rating']]
# Out:
#        Rating
# 0         4.1
# 1         3.9
# 2         4.7
# 3         4.5
# 4         4.3
# ...       ...
# 10834     4.0
# 10836     4.5
# 10837     5.0
# 10839     4.5
# 10840     4.5
#
# [8892 rows x 1 columns]

# %%
df['Rating'].isnull().sum()
# Out:
# 0

# %%
#create a new column as 'Rating_category' by converting ratings to high and low categories(>3.5 is high rest low)

df['Rating_category'] = df['Rating'].apply(lambda rating: 'high' if rating > 3.5 else 'low')
df['Rating_category']
# Out:
# 0        high
# 1        high
# 2        high
# 3        high
# 4        high
#          ...
# 10834    high
# 10836    high
# 10837    high
# 10839    high
# 10840    high
# Name: Rating_category, Length: 8892, dtype: object

# %% [markdown]
# * We encountered 1465 missing values present in the column 'Rating'.
# * So, we droped missing values in the column rating alone.
#                df = df.dropna(subset=['Rating'], axis=0)
#                df
# * And then we created a new column as 'Rating_category' by converting 'Rating' to high and low categories(>3.5 is high rest low).

# %% [markdown]
# # Question 7
# 7.Check the distribution of the newly created column 'Rating_category' and comment on the distribution

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.pie(df.groupby(['Rating_category'])['Rating_category'].count(),
        autopct='%1.1f%%',labels=df.groupby(['Rating_category'])['Rating_category'].count().index,startangle=90)
plt.title('Distribution of Rating_category')
plt.show()

# %% [markdown]
# # My Comment on the Distribution:
# * The pie chart illustrates the distribution of the 'Rating_category' column.
# * It is clear that a significant portion of the ratings falls into the 'high' category, occupying a large slice of the pie.
# * The 'low' category represents a smaller portion of the dataset, indicated by its smaller slice.
# * Hence, the majority of rating is above 3.5(high).

# %% [markdown]
# # Question 8
# 8.Convert the column "Reviews'' to numeric data type and check the presence of outliers in the column and
# handle the outliers using a transformation approach.(Hint: Use log transformation)

# %%
df['Reviews']=pd.to_numeric(df['Reviews'],errors='coerce')

# %%
plt.figure(figsize=(5,3))
plt.boxplot(df['Reviews'])
plt.show()

# %%
df['Reviews']=np.log1p(df['Reviews'])
plt.boxplot(df['Reviews'].dropna())
plt.show()

# %% [markdown]
# # Question 9
# 9.The column 'Size' contains alphanumeric values, treat the non numeric data and convert the column into
# suitable data type. (hint: Replace M with 1 million and K with 1 thousand, and drop the entries where
# size='Varies with device')

# %%
#Replace M with 1 million and K with 1 thousand
df['Size']=df['Size'].str.replace('M','*10**6').str.replace('k','*1000')
df['Size']
# Out:
# 0                  19*10**6
# 1                  14*10**6
# 2                 8.7*10**6
# 3                  25*10**6
# 4                 2.8*10**6
#                 ...
# 10834             2.6*10**6
# 10836              53*10**6
# 10837             3.6*10**6
# 10839    Varies with device
# 10840              19*10**6
# Name: Size, Length: 8892, dtype: object

# %%
#drop the entries where size='Varies with device'
df=df.drop(df[df['Size']=='Varies with device'].index)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#treat the non numeric data and convert the column into suitable data type
df['Size']=df['Size'].map(eval).astype(float)
df['Size']
# Out:
# 0        19000000.0
# 1        14000000.0
# 2         8700000.0
# 3        25000000.0
# 4         2800000.0
#             ...
# 10833      619000.0
# 10834     2600000.0
# 10836    53000000.0
# 10837     3600000.0
# 10840    19000000.0
# Name: Size, Length: 7424, dtype: float64

# %% [markdown]
# # Question 10
# 10.Check the column 'Installs', treat the unwanted characters and convert the column into a suitable data type.

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000+', '500,000,000+', '100+', '500+', '10+', '1,000,000,000+',
#        '5+', '50+', '1+'], dtype=object)

# %%
#unwanted characters where removed
df['Installs']=df['Installs'].str.replace(',','').astype(str)
df['Installs'].unique()
# Out:
# array(['10000+', '500000+', '5000000+', '50000000+', '100000+', '50000+',
#        '1000000+', '10000000+', '5000+', '100000000+', '1000+',
#        '500000000+', '100+', '500+', '10+', '1000000000+', '5+', '50+',
#        '1+'], dtype=object)

# %% [markdown]
# # Question 11
# 11.Check the column 'Price' , remove the unwanted characters and convert the column into a suitable data type.

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$6.99', '$7.99', '$3.99', '$5.99', '$2.99', '$1.99',
#        '$9.99', '$0.99', '$9.00', '$5.49', '$10.00', '$24.99', '$11.99',
#        '$79.99', '$16.99', '$14.99', '$29.99', '$12.99', '$3.49',
#        '$10.99', '$7.49', '$1.50', '$19.99', '$15.99', '$33.99', '$39.99',
#        '$2.49', '$4.49', '$1.70', '$1.49', '$3.88', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$1.59',
#        '$6.49', '$1.29', '$299.99', '$379.99', '$37.99', '$18.99',
#        '$389.99', '$8.49', '$1.75', '$14.00', '$2.00', '$3.08', '$2.59',
#        '$19.40', '$15.46', '$8.99', '$3.04', '$13.99', '$4.29', '$3.28',
#        '$4.60', '$1.00', '$2.90', '$1.97', '$2.56', '$1.20'], dtype=object)

# %%
df['Price']=df['Price'].str.replace('$','').astype(str)
df['Price'].unique()
# Out:
# C:\Users\Yuvharaaj\AppData\Local\Temp\ipykernel_112\3651945272.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price']=df['Price'].str.replace('$','').astype(str)
# array(['0', '4.99', '6.99', '7.99', '3.99', '5.99', '2.99', '1.99',
#        '9.99', '0.99', '9.00', '5.49', '10.00', '24.99', '11.99', '79.99',
#        '16.99', '14.99', '29.99', '12.99', '3.49', '10.99', '7.49',
#        '1.50', '19.99', '15.99', '33.99', '39.99', '2.49', '4.49', '1.70',
#        '1.49', '3.88', '399.99', '17.99', '400.00', '3.02', '1.76',
#        '4.84', '4.77', '1.61', '1.59', '6.49', '1.29', '299.99', '379.99',
#        '37.99', '18.99', '389.99', '8.49', '1.75', '14.00', '2.00',
#        '3.08', '2.59', '19.40', '15.46', '8.99', '3.04', '13.99', '4.29',
#        '3.28', '4.60', '1.00', '2.90', '1.97', '2.56', '1.20'],
# ...

# %% [markdown]
# # Question 12
# 12.Drop the columns which you think redundant for the analysis.(suggestion: drop column 'rating', since we
# created a new feature from it (i.e. rating_category) and the columns 'App', 'Rating' ,'Genres','Last Updated',
# 'Current Ver','Android Ver' columns since which are redundant for our analysis)

# %%
df = df.drop(columns=['App', 'Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver'])
df
# Out:
#                   Category    Reviews        Size   Installs  Type Price  \
# 0           ART_AND_DESIGN   5.075174  19000000.0     10000+  Free     0
# 1           ART_AND_DESIGN   6.875232  14000000.0    500000+  Free     0
# 2           ART_AND_DESIGN  11.379520   8700000.0   5000000+  Free     0
# 3           ART_AND_DESIGN  12.281389  25000000.0  50000000+  Free     0
# 4           ART_AND_DESIGN   6.875232   2800000.0    100000+  Free     0
# ...                    ...        ...         ...        ...   ...   ...
# 10833  BOOKS_AND_REFERENCE   3.806662    619000.0      1000+  Free     0
# 10834               FAMILY   2.079442   2600000.0       500+  Free     0
# 10836               FAMILY   3.663562  53000000.0      5000+  Free     0
# 10837               FAMILY   1.609438   3600000.0       100+  Free     0
# 10840            LIFESTYLE  12.894981  19000000.0  10000000+  Free     0
#
#       Content Rating Rating_category
# 0           Everyone            high
# ...

# %% [markdown]
# # Question 13
# 13.Encode the categorical columns.

# %%
cat_cols = df.select_dtypes(exclude = np.number).columns
cat_cols
# Out:
# Index(['Category', 'Installs', 'Type', 'Price', 'Content Rating',
#        'Rating_category'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in cat_cols:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#        Category    Reviews        Size  Installs  Type  Price  Content Rating  \
# 0             0   5.075174  19000000.0         4     0      0               1
# 1             0   6.875232  14000000.0        15     0      0               1
# 2             0  11.379520   8700000.0        16     0      0               1
# 3             0  12.281389  25000000.0        17     0      0               4
# 4             0   6.875232   2800000.0         5     0      0               1
# ...         ...        ...         ...       ...   ...    ...             ...
# 10833         3   3.806662    619000.0         3     0      0               1
# 10834        11   2.079442   2600000.0        12     0      0               1
# 10836        11   3.663562  53000000.0        13     0      0               1
# 10837        11   1.609438   3600000.0         2     0      0               1
# 10840        18  12.894981  19000000.0         7     0      0               1
#
#        Rating_category
# ...

# %% [markdown]
# # Question 14
# 14.Segregate the target and independent features (Hint: Use Rating_category as the target)

# %%
target=df[['Rating_category']]
target
# Out:
#        Rating_category
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 10833                0
# 10834                0
# 10836                0
# 10837                0
# 10840                0
#
# [7424 rows x 1 columns]

# %%
independent_features=df.drop('Rating_category',axis=1)
independent_features
# Out:
#        Category    Reviews        Size  Installs  Type  Price  Content Rating
# 0             0   5.075174  19000000.0         4     0      0               1
# 1             0   6.875232  14000000.0        15     0      0               1
# 2             0  11.379520   8700000.0        16     0      0               1
# 3             0  12.281389  25000000.0        17     0      0               4
# 4             0   6.875232   2800000.0         5     0      0               1
# ...         ...        ...         ...       ...   ...    ...             ...
# 10833         3   3.806662    619000.0         3     0      0               1
# 10834        11   2.079442   2600000.0        12     0      0               1
# 10836        11   3.663562  53000000.0        13     0      0               1
# 10837        11   1.609438   3600000.0         2     0      0               1
# 10840        18  12.894981  19000000.0         7     0      0               1
#
# [7424 rows x 7 columns]

# %% [markdown]
# # Question 15
# 15.Split the dataset into train and test.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent_features, target, test_size=0.2, random_state=42)

# %% [markdown]
# # Question 16
# 16.Standardize the data, so that the values are within a particular range

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df = scaler.fit_transform(df)
df = pd.DataFrame(df)
df
# Out:
#              0         1         2         3         4         5         6  \
# 0    -2.037666 -0.694347 -0.159928 -0.827581 -0.282029 -0.225602 -0.463220
# 1    -2.037666 -0.206386 -0.373300  1.549444 -0.282029 -0.225602 -0.463220
# 2    -2.037666  1.014637 -0.599475  1.765538 -0.282029 -0.225602 -0.463220
# 3    -2.037666  1.259116  0.096119  1.981631 -0.282029 -0.225602  2.517665
# 4    -2.037666 -0.206386 -0.851254 -0.611488 -0.282029 -0.225602 -0.463220
# ...        ...       ...       ...       ...       ...       ...       ...
# 7419 -1.669089 -1.038215 -0.944327 -1.043674 -0.282029 -0.225602 -0.463220
# 7420 -0.686217 -1.506431 -0.859789  0.901165 -0.282029 -0.225602 -0.463220
# 7421 -0.686217 -1.077007  1.291004  1.117258 -0.282029 -0.225602 -0.463220
# 7422 -0.686217 -1.633839 -0.817115 -1.259768 -0.282029 -0.225602 -0.463220
# 7423  0.173797  1.425449 -0.159928 -0.179302 -0.282029 -0.225602 -0.463220
#
#             7
# 0    -0.35358
# 1    -0.35358
# 2    -0.35358
# ...
